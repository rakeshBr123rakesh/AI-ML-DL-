# %% [markdown]
# # Vanishing gradient

# %% [markdown]
# ## load / import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout,Flatten,Dense
import keras

# %%
from sklearn.model_selection import train_test_split

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
from keras.initializers import random_normal

# %%
from keras.constraints import max_norm

# %%
from keras.optimizers import SGD

# %% [markdown]
# ## Loading the datasets

# %%
df=pd.read_csv("C:/Users/Rakesh/Desktop/career/AI ML AND DL Practice/Data/credit-card-dataset/Credit_card.csv")

# %%
labels=pd.read_csv("C:/Users/Rakesh/Desktop/career/AI ML AND DL Practice/Data/credit-card-dataset/Credit_card_label.csv")

# %%
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0        -18772.0         365243             1           0      0         0
# 1        -13557.0           -586             1           1      1         0
# 2             NaN           -586             1           1      1         0
# 3        -13557.0           -586             1           1      1         0
# 4        -13557.0           -586             1           1      1         0
#
#   Type_Occupation  Family_Members
# 0             NaN               2
# 1             NaN               2
# 2             NaN               2
# 3             NaN               2
# 4             NaN               2

# %%
labels.head()
# Out:
#     Ind_ID  label
# 0  5008827      1
# 1  5009744      1
# 2  5009746      1
# 3  5009749      1
# 4  5009752      1

# %%
dep="Approved"
df[dep]=labels.label.astype(int)
df.loc[df[dep]==1,"Status"]="Approved"
df.loc[df[dep]==0,"Status"]="Declined"

# %% [markdown]
# ## Feature Engineering

# %%
# Differentiate the  data bases on categorical data and numerical data or columns
cats = [
    'GENDER', 'Car_Owner', 'Propert_Owner', 'Type_Income',
    'EDUCATION', 'Marital_status', 'Housing_type', 'Mobile_phone',
    'Work_Phone', 'Phone', 'Type_Occupation', 'EMAIL_ID'
]

conts = [
    'CHILDREN', 'Family_Members', 'Annual_income',
    'Age', 'EmployedDaysOnly', 'UnemployedDaysOnly'
]

# %%
cats
# Out:
# ['GENDER',
#  'Car_Owner',
#  'Propert_Owner',
#  'Type_Income',
#  'EDUCATION',
#  'Marital_status',
#  'Housing_type',
#  'Mobile_phone',
#  'Work_Phone',
#  'Phone',
#  'Type_Occupation',
#  'EMAIL_ID']

# %%
def proc_data():
    df["Age"]=-df.Birthday_count//365
    df["EmployedDaysOnly"]=df.Employed_days.apply(lambda x: x if x>0 else 0)
    df["UnemployedDaysOnly"]=df.Employed_days.apply(lambda x: abs(x) if x<0 else 0) 

    for cat in cats:
        df[cat]=pd.Categorical(df[cat])

    modes=df.mode().iloc[0]
    df.fillna(modes,inplace=True)


proc_data()

# %%
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0       135000.0
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    ...  Work_Phone  Phone EMAIL_ID Type_Occupation Family_Members Approved  \
# 0  ...           0      0        0        Laborers              2        1
# 1  ...           1      1        0        Laborers              2        1
# 2  ...           1      1        0        Laborers              2        1
# 3  ...           1      1        0        Laborers              2        1
# 4  ...           1      1        0        Laborers              2        1
#
#      Status   Age  EmployedDaysOnly UnemployedDaysOnly
# 0  Approved  51.0            365243                  0
# 1  Approved  37.0                 0                586
# 2  Approved  37.0                 0                586
# 3  Approved  37.0                 0                586
# 4  Approved  37.0                 0                586
#
# [5 rows x 23 columns]

# %%
# Now data looks good

# %% [markdown]
# ## Oversampling due to heavily skewed data and Data Splitting

# %%
X=df[cats+conts]
y=df[dep]

# %%
X,y
# Out:
# (     GENDER Car_Owner Propert_Owner           Type_Income  \
#  0         M         Y             Y             Pensioner
#  1         F         Y             N  Commercial associate
#  2         F         Y             N  Commercial associate
#  3         F         Y             N  Commercial associate
#  4         F         Y             N  Commercial associate
#  ...     ...       ...           ...                   ...
#  1543      F         N             Y  Commercial associate
#  1544      F         N             N  Commercial associate
#  1545      M         Y             Y               Working
#  1546      M         Y             N               Working
#  1547      F         Y             Y               Working
#
#                            EDUCATION        Marital_status       Housing_type  \
#  0                  Higher education               Married  House / apartment
#  1                  Higher education               Married  House / apartment
#  2                  Higher education               Married  House / apartment
#  3                  Higher education               Married  House / apartment
#  4                  Higher education               Married  House / apartment
#  ...                             ...                   ...                ...
#  1543               Higher education               Married  House / apartment
#  1544              Incomplete higher  Single / not married  House / apartment
#  1545               Higher education               Married  House / apartment
#  1546  Secondary / secondary special        Civil marriage  House / apartment
#  1547               Higher education               Married  House / apartment
#
#       Mobile_phone Work_Phone Phone Type_Occupation EMAIL_ID  CHILDREN  \
#  0               1          0     0        Laborers        0         0
#  1               1          1     1        Laborers        0         0
#  2               1          1     1        Laborers        0         0
#  3               1          1     1        Laborers        0         0
#  4               1          1     1        Laborers        0         0
#  ...           ...        ...   ...             ...      ...       ...
#  1543            1          0     0        Managers        0         0
#  1544            1          0     0     Accountants        0         0
#  1545            1          0     0        Managers        0         2
#  1546            1          1     1         Drivers        0         0
#  1547            1          0     0        Laborers        0         0
#
#        Family_Members  Annual_income   Age  EmployedDaysOnly  \
#  0                  2       180000.0  51.0            365243
#  1                  2       315000.0  37.0                 0
#  2                  2       315000.0  37.0                 0
#  3                  2       135000.0  37.0                 0
#  4                  2       315000.0  37.0                 0
#  ...              ...            ...   ...               ...
#  1543               2       135000.0  32.0                 0
#  1544               1       225000.0  28.0                 0
#  1545               4       180000.0  36.0                 0
#  1546               2       270000.0  41.0                 0
#  1547               2       225000.0  45.0                 0
#
#        UnemployedDaysOnly
#  0                      0
#  1                    586
#  2                    586
#  3                    586
#  4                    586
#  ...                  ...
#  1543                2182
#  1544                1209
#  1545                2477
#  1546                 645
#  1547                2859
#
#  [1548 rows x 18 columns],
#  0       1
#  1       1
#  2       1
#  3       1
#  4       1
#         ..
#  1543    0
#  1544    0
#  1545    0
#  1546    0
#  1547    0
#  Name: Approved, Length: 1548, dtype: int64)

# %%
X_over,y_over=RandomOverSampler().fit_resample(X,y)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_over,y_over,test_size=0.25)

# %%
# Step 1: Convert categorical columns to category dtype
for col in cats:
    X_train[col] = X_train[col].astype('category')
    X_test[col] = X_test[col].astype('category')

# Step 2: Replace category values with integer codes
X_train[cats] = X_train[cats].apply(lambda x: x.cat.codes)
X_test[cats] = X_test[cats].apply(lambda x: x.cat.codes)

# %%
# Create model
model=Sequential()

# %%
model.add(Dense(10,activation="sigmoid",input_dim=18))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(10,activation="sigmoid"))

model.add(Dense(1,activation="sigmoid"))
# Out:
# C:\Users\Rakesh\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history=model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4813 - loss: 0.6943
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4905 - loss: 0.6936
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4896 - loss: 0.6933
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4925 - loss: 0.6933
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4866 - loss: 0.6934
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5046 - loss: 0.6935
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4881 - loss: 0.6935
# Epoch 8/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5109 - loss: 0.6935
# Epoch 9/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5012 - loss: 0.6935
# Epoch 10/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4944 - loss: 0.6933
# Epoch 11/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5036 - loss: 0.6934
# Epoch 12/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4871 - loss: 0.6934
# Epoch 13/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4828 - loss: 0.6937
# Epoch 14/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5051 - loss: 0.6935
# Epoch 15/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5012 - loss: 0.6934
# Epoch 16/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4910 - loss: 0.6935
# Epoch 17/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4925 - loss: 0.6935
# Epoch 18/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5017 - loss: 0.6933
# Epoch 19/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4934 - loss: 0.6936
# Epoch 20/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4871 - loss: 0.6939
# Epoch 21/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4886 - loss: 0.6936
# Epoch 22/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4818 - loss: 0.6935
# Epoch 23/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4910 - loss: 0.6933
# Epoch 24/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5002 - loss: 0.6935
# Epoch 25/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4968 - loss: 0.6933
# Epoch 26/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4837 - loss: 0.6934
# Epoch 27/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5012 - loss: 0.6934
# Epoch 28/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4876 - loss: 0.6934
# Epoch 29/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4959 - loss: 0.6935
# Epoch 30/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4954 - loss: 0.6934
# Epoch 31/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4915 - loss: 0.6933
# Epoch 32/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4944 - loss: 0.6935
# Epoch 33/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4760 - loss: 0.6933
# Epoch 34/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4803 - loss: 0.6936
# Epoch 35/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4954 - loss: 0.6933
# Epoch 36/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4920 - loss: 0.6935
# Epoch 37/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4886 - loss: 0.6934
# Epoch 38/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4857 - loss: 0.6935
# Epoch 39/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4842 - loss: 0.6933
# Epoch 40/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5032 - loss: 0.6937
# Epoch 41/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4998 - loss: 0.6934
# Epoch 42/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4973 - loss: 0.6938
# Epoch 43/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4852 - loss: 0.6934
# Epoch 44/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4920 - loss: 0.6939
# Epoch 45/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4706 - loss: 0.6937
# Epoch 46/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4706 - loss: 0.6937
# Epoch 47/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5056 - loss: 0.6936
# Epoch 48/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4954 - loss: 0.6935
# Epoch 49/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4823 - loss: 0.6935
# Epoch 50/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4857 - loss: 0.6934
# Epoch 51/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4934 - loss: 0.6933
# Epoch 52/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4857 - loss: 0.6934
# Epoch 53/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4930 - loss: 0.6935
# Epoch 54/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4939 - loss: 0.6935
# Epoch 55/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4983 - loss: 0.6933
# Epoch 56/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5017 - loss: 0.6935
# Epoch 57/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5012 - loss: 0.6933
# Epoch 58/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4866 - loss: 0.6935
# Epoch 59/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5007 - loss: 0.6934
# Epoch 60/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4881 - loss: 0.6934
# Epoch 61/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4910 - loss: 0.6934
# Epoch 62/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4808 - loss: 0.6933
# Epoch 63/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4939 - loss: 0.6938
# Epoch 64/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5002 - loss: 0.6933
# Epoch 65/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4934 - loss: 0.6934
# Epoch 66/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4847 - loss: 0.6935
# Epoch 67/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5012 - loss: 0.6934
# Epoch 68/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4862 - loss: 0.6935
# Epoch 69/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4803 - loss: 0.6935
# Epoch 70/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4993 - loss: 0.6934
# Epoch 71/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4886 - loss: 0.6936
# Epoch 72/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4915 - loss: 0.6934
# Epoch 73/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5012 - loss: 0.6936
# Epoch 74/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4857 - loss: 0.6934
# Epoch 75/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5012 - loss: 0.6933
# Epoch 76/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4925 - loss: 0.6934
# Epoch 77/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4978 - loss: 0.6934
# Epoch 78/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4900 - loss: 0.6937
# Epoch 79/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4784 - loss: 0.6934
# Epoch 80/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4915 - loss: 0.6933
# Epoch 81/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4959 - loss: 0.6934
# Epoch 82/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4983 - loss: 0.6934
# Epoch 83/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4832 - loss: 0.6934
# Epoch 84/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5027 - loss: 0.6933
# Epoch 85/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4847 - loss: 0.6937
# Epoch 86/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4910 - loss: 0.6936
# Epoch 87/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4959 - loss: 0.6933
# Epoch 88/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4896 - loss: 0.6936
# Epoch 89/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4910 - loss: 0.6933
# Epoch 90/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4944 - loss: 0.6933
# Epoch 91/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4828 - loss: 0.6933
# Epoch 92/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4862 - loss: 0.6937
# Epoch 93/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5012 - loss: 0.6933
# Epoch 94/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4915 - loss: 0.6933
# Epoch 95/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4973 - loss: 0.6936
# Epoch 96/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4973 - loss: 0.6933
# Epoch 97/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4896 - loss: 0.6933
# Epoch 98/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5002 - loss: 0.6933
# Epoch 99/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4983 - loss: 0.6933
# Epoch 100/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5075 - loss: 0.6931

# %%
# In the above model we can easily observe  acuuracy change per epochs tiny cahnges model wont learn in that time

# %% [markdown]
# ## Solution for Vanishing Gradient Problem

# %%
# Scaling
scaler=StandardScaler()
X_train_scaler=scaler.fit_transform(X_train)
X_test_scaler=scaler.transform(X_test)

# %%
# Creating new model with name of model2
model2=Sequential()
model2.add(Dense(128,activation="relu",input_dim=18))
model2.add(Dropout(0.5))
model2.add(Dense(256,activation="relu"))
model2.add(Dropout(0.5))
model2.add(Dense(128,activation="relu"))
model2.add(Dropout(0.5))
model2.add(Dense(64,activation="relu"))
model2.add(Dropout(0.5))
model2.add(Dense(1,activation="sigmoid"))
# Out:
# C:\Users\Rakesh\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
earlystopping=EarlyStopping(patience=10,monitor="val_loss",restore_best_weights=True)
model2.compile(optimizer=Adam(learning_rate=0.001),loss="binary_crossentropy",metrics=["accuracy"])

# %%
history2=model2.fit(X_train_scaler,y_train,epochs=100,validation_data=(X_test_scaler,y_test),batch_size=32,
                    callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5066 - loss: 0.7357 - val_accuracy: 0.5531 - val_loss: 0.6880
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5304 - loss: 0.7008 - val_accuracy: 0.5677 - val_loss: 0.6871
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5299 - loss: 0.6922 - val_accuracy: 0.5997 - val_loss: 0.6811
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5488 - loss: 0.6887 - val_accuracy: 0.6026 - val_loss: 0.6784
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5765 - loss: 0.6802 - val_accuracy: 0.6099 - val_loss: 0.6695
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5920 - loss: 0.6661 - val_accuracy: 0.6201 - val_loss: 0.6556
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9009 - loss: 0.2300 - val_accuracy: 0.9418 - val_loss: 0.1703
# Epoch 82/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9174 - loss: 0.2125 - val_accuracy: 0.9447 - val_loss: 0.1621
# Epoch 83/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9169 - loss: 0.2037 - val_accuracy: 0.9432 - val_loss: 0.1679
# Epoch 84/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9208 - loss: 0.2007 - val_accuracy: 0.9491 - val_loss: 0.1508
# Epoch 85/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9169 - loss: 0.2056 - val_accuracy: 0.9491 - val_loss: 0.1634
# Epoch 86/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9208 - loss: 0.1970 - val_accuracy: 0.9432 - val_loss: 0.1634
# Epoch 87/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9174 - loss: 0.2159 - val_accuracy: 0.9418 - val_loss: 0.1608
# Epoch 88/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9155 - loss: 0.2023 - val_accuracy: 0.9476 - val_loss: 0.1590
# Epoch 89/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9267 - loss: 0.1980 - val_accuracy: 0.9578 - val_loss: 0.1475
# Epoch 90/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9140 - loss: 0.2145 - val_accuracy: 0.9461 - val_loss: 0.1566
# Epoch 91/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9199 - loss: 0.1944 - val_accuracy: 0.9432 - val_loss: 0.1585
# Epoch 92/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9223 - loss: 0.1923 - val_accuracy: 0.9432 - val_loss: 0.1612
# Epoch 93/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9145 - loss: 0.2063 - val_accuracy: 0.9520 - val_loss: 0.1568
# Epoch 94/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9194 - loss: 0.2032 - val_accuracy: 0.9505 - val_loss: 0.1560
# Epoch 95/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9213 - loss: 0.1990 - val_accuracy: 0.9520 - val_loss: 0.1473
# Epoch 96/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9208 - loss: 0.1896 - val_accuracy: 0.9491 - val_loss: 0.1542
# Epoch 97/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9257 - loss: 0.2045 - val_accuracy: 0.9563 - val_loss: 0.1473
# Epoch 98/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9267 - loss: 0.1826 - val_accuracy: 0.9491 - val_loss: 0.1490
# Epoch 99/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9247 - loss: 0.1811 - val_accuracy: 0.9549 - val_loss: 0.1468
# Epoch 100/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 0.1694 - val_accuracy: 0.9534 - val_loss: 0.1405

# %%
# Here we can clearly see the increases of teh model accuracy for every epochs

# %%
prediction=model2.predict(X_test_scaler)
rounded_prediction=np.round(prediction)
report=classification_report(y_test,rounded_prediction)
print(f"The classification report is {report}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# The classification report is               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95       346
#            1       0.92      0.99      0.95       341
#
#     accuracy                           0.95       687
#    macro avg       0.96      0.95      0.95       687
# weighted avg       0.96      0.95      0.95       687

# %% [markdown]
# # Exploding gradient

# %% [markdown]
# ## Lets Build and train a model with Exploding gradient problem

# %%
model=Sequential()
model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0),input_dim=18))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(10,activation="tanh",kernel_initializer=random_normal(mean=0.0,stddev=1.0)))

model.add(Dense(1,activation="sigmoid"))
# Out:
# C:\Users\Rakesh\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer=SGD(learning_rate=1.0)
model.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4857 - loss: 0.7811
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4915 - loss: 0.7245
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4852 - loss: 0.7273
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5153 - loss: 0.7185
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5041 - loss: 0.7157
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4920 - loss: 0.7200
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5017 - loss: 0.7032
# Epoch 8/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4857 - loss: 0.7239
# Epoch 9/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5138 - loss: 0.7169
# Epoch 10/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5046 - loss: 0.7142
# Epoch 11/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4954 - loss: 0.7419
# Epoch 12/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5061 - loss: 0.7067
# Epoch 13/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4968 - loss: 0.7167
# Epoch 14/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.